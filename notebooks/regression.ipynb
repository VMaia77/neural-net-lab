# %%
# %cd ..

import os
import urllib.request
from zipfile import ZipFile
import cv2
import numpy as np
from sklearn.model_selection import train_test_split
from src.model.neural_network import NeuralNetwork
from src.utils.plots import plot_epochs_history
import matplotlib.pyplot as plt

np.set_printoptions(linewidth=200)

# %%
X = np.arange(0, 10, 0.1)

y = np.sin(X)

X = X.reshape(X.shape[0], 1)
y = y.reshape(y.shape[0], 1)

# shuffle the training dataset
keys = np.array(range(X.shape[0]))
np.random.shuffle(keys)
X = X[keys]
y = y[keys]

# %%
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
start_params = dict(input_shape = X_train.shape[1], output_n_neurons = y_train.shape[1], output_activation='linear', accuracy= 'regression_mae')

model = NeuralNetwork(**start_params)

# add layers
params = dict(loss = 'mean_squared_error', optimizer = 'adam', 
        epochs = 1000, batch_size = None,        
        n_layers = 2, n_neurons = 100, 
        learning_rate = 0.001)

model.set_params(**params)

model.fit(X, y, validation_data=(X_val, y_val), print_every_n_steps=100)

# %% [markdown]
# ### Plot accumulated epoch losses and validation losses
#
# The validation loss (in **orange**) usually starts smaller than the epoch losses because the values used to calculate the epoch loss are computed before the parameter update and the validation loss is computed after all parameter updates of the epoch.

# %%
plot_epochs_history([model.accumulated_epoch_losses, model.validation_epoch_losses], 'Loss')

# %%
model.evaluate(X, y)
# Out:
# 0-> Acc: -0.003 Loss: 0.000
# (1.2292260850183073e-05, -0.0032778366090759786)

# %%
pred = model.predict(X)

plt.scatter(X, y)
plt.scatter(X, pred)
plt.show()

# %%
pred_val = model.predict(X_val)

plt.scatter(X_val, y_val)
plt.scatter(X_val, pred_val)
plt.show()

# %%
model.predict(X)
# Out:
# array([[ 7.13716809e-01],
#        [ 9.59749324e-02],
#        [-9.58726322e-01],
#        [ 7.91376363e-01],
#        [-9.26008701e-01],
#        [-5.52948650e-01],
#        [ 8.52752682e-01],
#        [ 1.42845677e-01],
#        [ 8.91460165e-01],
#        [ 7.26359368e-01],
#        [-1.81334724e-01],
#        [ 9.65396477e-01],
#        [-5.30391104e-01],
#        [ 9.88796440e-01],
#        [ 1.17645090e-01],
#        [-9.82398084e-01],
#        [-7.07480932e-01],
#        [ 6.72817288e-01],
#        [ 9.99545825e-01],
#        [ 5.16994857e-01],
#        [ 9.93232057e-01],
#        [ 3.12775107e-01],
#        [ 9.70058621e-01],
#        [-3.54542510e-01],
#        [-8.27233191e-02],
#        [-7.56885370e-01],
#        [ 9.06966331e-01],
#        [-9.92636340e-01],
#        [ 2.00757383e-04],
#        [ 4.92350845e-01],
#        [ 4.78551199e-01],
#        [ 9.68393237e-01],
#        [ 3.06520130e-01],
#        [ 5.64717827e-01],
#        [-9.78018226e-01],
#        [ 6.63001612e-01],
#        [ 7.31694830e-01],
#        [-1.65667470e-01],
#        [-6.10731760e-01],
#        [-2.56061682e-01],
#        [ 9.32122813e-01],
#        [ 9.46524140e-01],
#        [-1.59624080e-01],
#        [ 4.05533981e-01],
#        [-6.33530500e-01],
#        [ 1.15025894e-01],
#        [ 7.87174388e-01],
#        [ 8.63735295e-01],
#        [-3.72008641e-01],
#        [-8.30837298e-01],
#        [ 8.96295474e-01],
#        [-3.49281151e-01],
#        [ 2.13900500e-01],
#        [-8.17698039e-01],
#        [ 2.12082610e-01],
#        [ 9.75955050e-01],
#        [ 9.94212804e-01],
#        [ 4.20032330e-02],
#        [ 2.39037868e-01],
#        [-7.71903724e-01],
#        [-9.51628701e-01],
#        [-1.00030754e+00],
#        [-8.70720262e-01],
#        [-4.48667706e-01],
#        [ 4.30623170e-01],
#        [ 4.00957650e-01],
#        [-2.60104990e-01],
#        [ 5.96405312e-01],
#        [ 1.97941384e-01],
#        [ 9.98686819e-01],
#        [ 2.99907837e-01],
#        [ 3.33602161e-01],
#        [-4.65410258e-01],
#        [ 7.42629976e-01],
#        [ 9.38283500e-01],
#        [ 4.95395170e-01],
#        [ 8.12442663e-01],
#        [ 3.90480635e-01],
#        [ 8.00333073e-01],
#        [ 1.61512874e-02],
#        [-8.83173721e-01],
#        [-9.17895633e-01],
#        [-9.95772051e-01],
#        [ 5.79167709e-01],
#        [ 6.40259230e-01],
#        [ 2.32075702e-02],
#        [ 8.52037083e-01],
#        [ 9.98649743e-01],
#        [ 9.83634143e-01],
#        [ 9.87495915e-01],
#        [-5.88104234e-02],
#        [ 5.85870746e-01],
#        [ 8.45854277e-01],
#        [-4.42500620e-01],
#        [ 9.40557560e-01],
#        [ 9.05172291e-01],
#        [-7.12299499e-02],
#        [-6.88785374e-01],
#        [-2.76784933e-01],
#        [ 6.61342372e-01]])

# %%
model.save_model('regression.model')

# %%
model = NeuralNetwork.load('regression.model')

model.evaluate(X_val, y_val)
# Out:
# 0-> Acc: -0.002 Loss: 0.000
# (3.639112788838398e-06, -0.0020832619351944933)
